# %%
# basic web scarping Alex the Analyst tutorial 
# https://www.youtube.com/watch?v=bargNl2WeN4&list=PLUaB-1hjhk8G-xVXA5FxT2cLNzd87GInr

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.latlong.net/category/national-parks-236-42.html'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="vZm0ZMT-vb8aUejnNpsfLSZLYrizCqzwdIISmcwN9Y4" name="google-site-verification"/>
# <link href="/favicon.png" rel="icon" type="image/png"/>
# ...

# %%
table = soup.find_all('table')

# %%
print(table)
# Out:
# [<table><tr><th>Place Name</th><th>Latitude</th><th>Longitude</th></tr><tr>
# <td><a href="/place/grand-teton-national-park-wy-usa-33300.html" title="Grand Teton National Park, WY, USA">Grand Teton National Park, WY, USA</a></td><td>43.790802</td><td>-110.684944</td>
# </tr><tr>
# <td><a href="/place/grand-canyon-national-park-az-usa-33179.html" title="Grand Canyon National Park, AZ, USA">Grand Canyon National Park, AZ, USA</a></td><td>36.266033</td><td>-112.363808</td>
# </tr><tr>
# <td><a href="/place/capitol-reef-national-park-ut-usa-31746.html" title="Capitol Reef National Park, UT, USA">Capitol Reef National Park, UT, USA</a></td><td>38.089600</td><td>-111.149910</td>
# </tr><tr>
# <td><a href="/place/pinnacles-national-park-ca-usa-31743.html" title="Pinnacles National Park, CA, USA">Pinnacles National Park, CA, USA</a></td><td>36.491508</td><td>-121.197243</td>
# </tr><tr>
# ...

# %%
titles = soup.find_all('th')

# %%
titles
# Out:
# [<th>Place Name</th>, <th>Latitude</th>, <th>Longitude</th>]

# %%
titles = [title.text.strip() for title in titles]
print(titles)
# Out:
# ['Place Name', 'Latitude', 'Longitude']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = titles)

df
# Out:
# Empty DataFrame
# Columns: [Place Name, Latitude, Longitude]
# Index: []

# %%
column_data = soup.find_all('tr')
print(column_data)
# Out:
# [<tr><th>Place Name</th><th>Latitude</th><th>Longitude</th></tr>, <tr>
# <td><a href="/place/grand-teton-national-park-wy-usa-33300.html" title="Grand Teton National Park, WY, USA">Grand Teton National Park, WY, USA</a></td><td>43.790802</td><td>-110.684944</td>
# </tr>, <tr>
# <td><a href="/place/grand-canyon-national-park-az-usa-33179.html" title="Grand Canyon National Park, AZ, USA">Grand Canyon National Park, AZ, USA</a></td><td>36.266033</td><td>-112.363808</td>
# </tr>, <tr>
# <td><a href="/place/capitol-reef-national-park-ut-usa-31746.html" title="Capitol Reef National Park, UT, USA">Capitol Reef National Park, UT, USA</a></td><td>38.089600</td><td>-111.149910</td>
# </tr>, <tr>
# <td><a href="/place/pinnacles-national-park-ca-usa-31743.html" title="Pinnacles National Park, CA, USA">Pinnacles National Park, CA, USA</a></td><td>36.491508</td><td>-121.197243</td>
# </tr>, <tr>
# ...

# %%
column_data = soup.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                    Place Name   Latitude    Longitude
# 0          Grand Teton National Park, WY, USA  43.790802  -110.684944
# 1         Grand Canyon National Park, AZ, USA  36.266033  -112.363808
# 2         Capitol Reef National Park, UT, USA  38.089600  -111.149910
# 3            Pinnacles National Park, CA, USA  36.491508  -121.197243
# 4       Rocky Mountain National Park, CO, USA  40.343182  -105.688103
# ..                                        ...        ...          ...
# 80           Mt Hood National Forest, OR, USA  45.227173  -121.839455
# 81      Bryce Canyon National Park, Utah, USA  37.593048  -112.187332
# 82        Mammoth Cave National Park, KY, USA  37.183640   -86.159943
# 83  Redwood National and State Parks, CA, USA  41.213181  -124.004631
# 84             Yellowstone National Park, USA  44.423691  -110.588516
#
# [85 rows x 3 columns]

# %%
df.to_csv(r'/Users/melanietidsworth/Downloads/QGIS-Training-Data-master/projects/national-parks.csv')
